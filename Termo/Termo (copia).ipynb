# %%
# %pylab inline
import matplotlib.pyplot as plt
import numpy as np
from numpy import pi
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
t=np.loadtxt(open('Datos.txt','r'))

# %%
#se filtran los datos en diferentes vectores.
frequency=t[:,0]
MonopoleSpectrum=t[:,1]
ResidualMonopoleS=t[:,2]
SpectrumUncertain=t[:,3]
modelGalaxySpectrum=t[:,4]

#numero de datos
size=shape(frequency)[0]
size
# Out:
# 43

# %%
plt.plot(frequency)

# %%
plt.plot(MonopoleSpectrum)

# %%
plt.plot(SpectrumUncertain)

# %%
plt.plot(ResidualMonopoleS)

# %%
plt.plot(modelGalaxySpectrum)
